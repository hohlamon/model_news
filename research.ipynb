# %%
import gensim

# %%
model_rt = gensim.models.Word2Vec.load('model_rt.wordvectors')

# %%
model_meduza = gensim.models.Word2Vec.load('model_meduza.wordvectors')

# %%
model_rt.wv.most_similar('жёлтый_ADJ', topn = 20)
# Out:
# [('жилет_NOUN', 0.8679708242416382),
#  ('акция_NOUN', 0.6223999261856079),
#  ('протестный_ADJ', 0.6202284097671509),
#  ('оранжевый_ADJ', 0.6155855059623718),
#  ('протест_NOUN', 0.5909684896469116),
#  ('интер_PROPN', 0.5858240127563477),
#  ('протестовать_VERB', 0.574246346950531),
#  ('карточка_NOUN', 0.5696172714233398),
#  ('ривер_X', 0.5586483478546143),
#  ('лилль_PROPN', 0.5388255715370178),
#  ('фурия_NOUN', 0.5364245176315308),
#  ('енисей_PROPN', 0.5354747176170349),
#  ('свеча_NOUN', 0.531343400478363),
#  ('антиглобалист_NOUN', 0.5312638878822327),
#  ('демонстрация_NOUN', 0.5304859280586243),
#  ('субботний_ADJ', 0.5301504731178284),
#  ('вильярреал_NOUN', 0.5295596718788147),
#  ('боруссии_NOUN', 0.5280122756958008),
#  ('плейт_X', 0.5265085101127625),
#  ('лион_PROPN', 0.5260302424430847)]

# %%
model_meduza.wv.most_similar('жёлтый_ADJ', topn = 20)
# Out:
# [('цветной_ADJ', 0.7998216152191162),
#  ('синий_ADJ', 0.7923029661178589),
#  ('жилет_NOUN', 0.7889761924743652),
#  ('красный_ADJ', 0.7519413828849792),
#  ('тюльпан_NOUN', 0.748959481716156),
#  ('песок_NOUN', 0.7473295331001282),
#  ('голубой_ADJ', 0.7295907735824585),
#  ('ведро_NOUN', 0.727308988571167),
#  ('зелёный_ADJ', 0.7219002842903137),
#  ('бак_NOUN', 0.717401385307312),
#  ('вверх_ADV', 0.7148515582084656),
#  ('алый_ADJ', 0.7140890955924988),
#  ('ограждение_NOUN', 0.7023389935493469),
#  ('зажигательный_ADJ', 0.6992892622947693),
#  ('коктейль_NOUN', 0.6986023783683777),
#  ('металлический_ADJ', 0.6979859471321106),
#  ('асфальт_NOUN', 0.6963827610015869),
#  ('шарик_NOUN', 0.6956139206886292),
#  ('стекло_NOUN', 0.6938177943229675),
#  ('плита_NOUN', 0.6913453936576843)]

# %%
model_rt.wv.most_similar('демонстрант_NOUN', topn = 20)
# Out:
# [('полицейский_NOUN', 0.7952880859375),
#  ('манифестант_NOUN', 0.7700504660606384),
#  ('злоумышленник_NOUN', 0.7694268822669983),
#  ('прохожий_NOUN', 0.7540052533149719),
#  ('протестовать_VERB', 0.7496852278709412),
#  ('граната_NOUN', 0.7314420938491821),
#  ('правоохранитель_NOUN', 0.7303114533424377),
#  ('резиновый_ADJ', 0.7214031219482422),
#  ('митинговать_VERB', 0.7207948565483093),
#  ('грабитель_NOUN', 0.7072550654411316),
#  ('преступник_NOUN', 0.7063701152801514),
#  ('нож_NOUN', 0.70262610912323),
#  ('пассажирка_NOUN', 0.6989055275917053),
#  ('бандит_NOUN', 0.6949573755264282),
#  ('подозреваемый_NOUN', 0.6930416822433472),
#  ('арка_NOUN', 0.6904929280281067),
#  ('баррикада_NOUN', 0.6900995373725891),
#  ('нападать_VERB', 0.6879988312721252),
#  ('участковый_NOUN', 0.6850976943969727),
#  ('иномарка_NOUN', 0.6833086013793945)]

# %%
model_meduza.wv.most_similar('демонстрант_NOUN', topn = 20)
# Out:
# [('протестовать_VERB', 0.8944382071495056),
#  ('митинговать_VERB', 0.7809681296348572),
#  ('разгон_NOUN', 0.6992796063423157),
#  ('слезоточивый_ADJ', 0.6751092672348022),
#  ('столкновение_NOUN', 0.669348418712616),
#  ('прохожий_NOUN', 0.663638710975647),
#  ('омон_PROPN', 0.6614647507667542),
#  ('силовик_NOUN', 0.6610859632492065),
#  ('оцепление_NOUN', 0.656055212020874),
#  ('демонстрация_NOUN', 0.6553245782852173),
#  ('омоновец_NOUN', 0.6527701020240784),
#  ('полицейский_NOUN', 0.6525481343269348),
#  ('водомёт_NOUN', 0.6510469317436218),
#  ('казак_NOUN', 0.6506161093711853),
#  ('стихийный_ADJ', 0.6486629247665405),
#  ('протест_NOUN', 0.6480299830436707),
#  ('жилет_NOUN', 0.6474184393882751),
#  ('пикет_NOUN', 0.6467329859733582),
#  ('шествие_NOUN', 0.6464296579360962),
#  ('дымовой_ADJ', 0.6426780819892883)]

# %%
model_rt.wv.most_similar('санкция_NOUN', topn = 20)
# Out:
# [('ограничение_NOUN', 0.7155987024307251),
#  ('введение_NOUN', 0.7087727189064026),
#  ('санкционный_ADJ', 0.694912314414978),
#  ('пошлина_NOUN', 0.6710303425788879),
#  ('евросоюз_PROPN', 0.6318324208259583),
#  ('агрессия_NOUN', 0.6055845022201538),
#  ('заблуждение_NOUN', 0.6041548252105713),
#  ('эмбарго_NOUN', 0.6039933562278748),
#  ('ес_PROPN', 0.5945785045623779),
#  ('антироссийский_ADJ', 0.5921627283096313),
#  ('договор_NOUN', 0.5874170660972595),
#  ('мера_NOUN', 0.5861958265304565),
#  ('ограничительный_ADJ', 0.5803422927856445),
#  ('сделка_NOUN', 0.5746322870254517),
#  ('истерия_NOUN', 0.5727882981300354),
#  ('политика_NOUN', 0.5663167238235474),
#  ('контрсанкций_NOUN', 0.5658068060874939),
#  ('давление_NOUN', 0.5583212375640869),
#  ('риторика_NOUN', 0.5549007654190063),
#  ('шаг_NOUN', 0.5487051606178284)]

# %%
model_meduza.wv.most_similar('санкция_NOUN', topn = 20)
# Out:
# [('ограничение_NOUN', 0.7001500725746155),
#  ('пошлина_NOUN', 0.6832016110420227),
#  ('введение_NOUN', 0.680605411529541),
#  ('санкционный_ADJ', 0.626590371131897),
#  ('иран_PROPN', 0.6218281984329224),
#  ('евросоюз_PROPN', 0.6201626658439636),
#  ('запрет_NOUN', 0.6186222434043884),
#  ('сделка_NOUN', 0.5997142195701599),
#  ('отсрочка_NOUN', 0.5893911123275757),
#  ('ес_PROPN', 0.5885072946548462),
#  ('импорт_NOUN', 0.5822325348854065),
#  ('законодательство_NOUN', 0.5786343812942505),
#  ('изоляция_NOUN', 0.5748727917671204),
#  ('соглашение_NOUN', 0.5730751752853394),
#  ('минфин_PROPN', 0.5719538927078247),
#  ('вооружение_NOUN', 0.5698518753051758),
#  ('эмбарго_NOUN', 0.5635662078857422),
#  ('доктрина_NOUN', 0.5589331984519958),
#  ('поправка_NOUN', 0.5535207390785217),
#  ('обязательство_NOUN', 0.5508089661598206)]
